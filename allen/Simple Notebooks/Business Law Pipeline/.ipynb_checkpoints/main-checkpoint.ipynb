# %% [markdown]
# # Imports, Functions

# %%
# %matplotlib inline
from __future__ import division
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import sklearn
from sklearn import metrics
from sklearn.cross_validation import train_test_split, cross_val_score
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from copy import deepcopy
import sys
from sklearn import metrics
import kmeansdistance as KD
from sklearn.cluster import KMeans

def getGradsClusterDF(df, cluster_list):
    return pd.DataFrame({'Graduated':df['Graduated'],'ClusterLbl':cluster_list})

def printContingencyTable(y,ypred,labels):
    confusion_matrix = metrics.confusion_matrix(y, ypred)
    plt.matshow(confusion_matrix)
    plt.title('Confusion matrix')
    plt.colorbar()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    print pd.crosstab(y,ypred,rownames=[labels[0]],colnames=[labels[1]])

def plotROC(y_test,y_pred):
    #y_pred can consist of Boolean labels or probabilities, w/ the obvious implications for curve character
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,y_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate, 'b', label='AUC = %0.2f' %roc_auc)
    plt.legend(loc='lower right')
    plt.plot([0, 1], [0, 1], 'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

def encode(s):
    v = re.split(r':',s)
    x = v[1][1:]
    out = 0.0
    if x=='A+':
        out=4.0
    if x=='A':
        out=4.0
    if x=='A-':
        out=3.7
    if x=='B+':
        out=3.3
    if x=='B':
        out=3.0
    if x=='B-':
        out=2.7
    if x=='C+':
        out=2.3
    if x=='C':
        out=2.0
    if x=='C-':
        out=1.7
    if x=='D+':
        out=1.3
    if x=='D':
        out=1.0
    if x=='D-':
        out=0.7
    if x=='F':
        out=0.0
    if x=='NA':
        out = 0.0
    if x=='CR':
        out=2.0
    return out-2.0

def determineColumnRange(data):
    notClassStrings = ['Major_Cd','N_Terms','Graduated','Transfer_Cr','Inst_Cr']
    newset = data.columns - notClassStrings
    classIndexStart = list(data.columns).index(newset[0])
    classIndexEnd = len(data.columns)-1
    return (classIndexStart,classIndexEnd)

def applyEncoding(data):
    data['Graduated'].replace(to_replace=('N','Y'), value=(0,1), inplace=True)
    gpaDF=data[data.columns[classIndexStart:]].applymap(encode) #apply encoding function 
    gpaDF[data.columns[:classIndexStart]]=data[data.columns[:classIndexStart]]
    return gpaDF[data.columns]

def getPCADataFrame(columns, pca, n_components=2):
    pcaDF=pd.DataFrame({'class':columns})
    for i in range(1,n_components+1):#add principal component columns
        pcaDF['PC'+str(i)]=pca.components_[i-1]
    return pcaDF

def getLogRegDataFrame(columns,coeffs):
    logregDF = pd.DataFrame({'class':columns,'coeff':coeffs})
    return logregDF

def CH_index(X, labels, centroids):
    '''
    https://github.com/scampion/scikit-learn/blob/master/scikits/learn/cluster/__init__.py
    '''
    mean = np.mean(X,axis=0) 
    B = np.sum([ np.sum(labels==i)*(c - mean)**2 for i,c in enumerate(centroids)])
    W = np.sum([ (x-centroids[labels[i]])**2 for i, x in enumerate(X)])
    c = len(centroids)
    n = len(X)
    return ((n-c)*B )/1.0/((c-1)*W)

# %% [markdown]
# # ALL EDITS IN THIS CELL, EVERYTHING AFTER IS AUTOMATED

# %%
data = pd.read_csv('blaw_redacted.csv')#change dataset here
firstClasses = ['ECON160','ECON161','ACCT220']#type in typical first three classes
data.head()
# Out:
#          Major_Cd N_Terms  Graduated  Transfer_Cr Inst_Cr ACCT220 ACCT230  \
# 230726B         1       N       11.0           91   0:0NA   0:0NA   1:1C+
# 230726B         1       N       33.7           41   0:0NA   0:0NA   1:1C+
# 230726B         2       N        6.0           70   0:0NA   0:0NA    1:1B
# 230726B         2       N        6.0           90   0:0NA   0:0NA    1:1B
# 230726B         1       N        3.0           38   0:0NA   0:0NA   1:1D-
#
#         BLAW280 COMP100 ECON160   ...   SOM120 MATH150A MATH150B MATH140  \
# 230726B    1:0W   0:0NA   0:0NA   ...    0:0NA    0:0NA    0:0NA   0:0NA
# 230726B   0:0NA   0:0NA   0:0NA   ...    0:0NA    0:0NA    0:0NA   0:0NA
# 230726B    2:0F   0:0NA   0:0NA   ...    0:0NA    0:0NA      1:0   0:0NA
# 230726B   1:1B-    1:1C    1:1B   ...    0:0NA    0:0NA    0:0NA   0:0NA
# 230726B    1:1C   0:0NA   0:0NA   ...    0:0NA    0:0NA    0:0NA   0:0NA
#
#         BUS302 FIN303 MGT360 MKT304 SOM306 BLAW308
# 230726B  0:0NA  0:0NA  0:0NA   1:0F  0:0NA   2:1B-
# 230726B  0:0NA  0:0NA  0:0NA  0:0NA  0:0NA   1:1C-
# 230726B  0:0NA  0:0NA  0:0NA  0:0NA  0:0NA   1:1C+
# 230726B  0:0NA  2:1D-    1:0  2:1B+  0:0NA    1:1A
# 230726B  0:0NA  0:0NA  0:0NA  0:0NA  0:0NA   0:0NA
#
# [5 rows x 23 columns]

# %%
cols = data.columns.tolist()
cols = [cols[0]]+[cols[2]]+[cols[1]]+cols[3:]
data.columns = cols
data.head()
# Out:
#          Major_Cd Graduated  N_Terms  Transfer_Cr Inst_Cr ACCT220 ACCT230  \
# 230726B         1         N     11.0           91   0:0NA   0:0NA   1:1C+
# 230726B         1         N     33.7           41   0:0NA   0:0NA   1:1C+
# 230726B         2         N      6.0           70   0:0NA   0:0NA    1:1B
# 230726B         2         N      6.0           90   0:0NA   0:0NA    1:1B
# 230726B         1         N      3.0           38   0:0NA   0:0NA   1:1D-
#
#         BLAW280 COMP100 ECON160   ...   SOM120 MATH150A MATH150B MATH140  \
# 230726B    1:0W   0:0NA   0:0NA   ...    0:0NA    0:0NA    0:0NA   0:0NA
# 230726B   0:0NA   0:0NA   0:0NA   ...    0:0NA    0:0NA    0:0NA   0:0NA
# 230726B    2:0F   0:0NA   0:0NA   ...    0:0NA    0:0NA      1:0   0:0NA
# 230726B   1:1B-    1:1C    1:1B   ...    0:0NA    0:0NA    0:0NA   0:0NA
# 230726B    1:1C   0:0NA   0:0NA   ...    0:0NA    0:0NA    0:0NA   0:0NA
#
#         BUS302 FIN303 MGT360 MKT304 SOM306 BLAW308
# 230726B  0:0NA  0:0NA  0:0NA   1:0F  0:0NA   2:1B-
# 230726B  0:0NA  0:0NA  0:0NA  0:0NA  0:0NA   1:1C-
# 230726B  0:0NA  0:0NA  0:0NA  0:0NA  0:0NA   1:1C+
# 230726B  0:0NA  2:1D-    1:0  2:1B+  0:0NA    1:1A
# 230726B  0:0NA  0:0NA  0:0NA  0:0NA  0:0NA   0:0NA
#
# [5 rows x 23 columns]

# %%
classIndexStart,classIndexEnd = determineColumnRange(data)

gpaDF = applyEncoding(data)#apply encoding, return working dataframe for future operations

col = range(classIndexStart,classIndexEnd+1)#returns the range of class columns

gpaDF.head()
# Out:
#          Major_Cd  Graduated  N_Terms  Transfer_Cr Inst_Cr  ACCT220  ACCT230  \
# 230726B         1          0     11.0           91   0:0NA       -2      0.3
# 230726B         1          0     33.7           41   0:0NA       -2      0.3
# 230726B         2          0      6.0           70   0:0NA       -2      1.0
# 230726B         2          0      6.0           90   0:0NA       -2      1.0
# 230726B         1          0      3.0           38   0:0NA       -2     -1.3
#
#          BLAW280  COMP100  ECON160   ...     SOM120  MATH150A  MATH150B  \
# 230726B     -2.0       -2       -2   ...         -2        -2        -2
# 230726B     -2.0       -2       -2   ...         -2        -2        -2
# 230726B     -2.0       -2       -2   ...         -2        -2        -2
# 230726B      0.7        0        1   ...         -2        -2        -2
# 230726B      0.0       -2       -2   ...         -2        -2        -2
#
#          MATH140  BUS302  FIN303  MGT360  MKT304  SOM306  BLAW308
# 230726B       -2      -2    -2.0      -2    -2.0      -2      0.7
# 230726B       -2      -2    -2.0      -2    -2.0      -2     -0.3
# 230726B       -2      -2    -2.0      -2    -2.0      -2      0.3
# 230726B       -2      -2    -1.3      -2     1.3      -2      2.0
# 230726B       -2      -2    -2.0      -2    -2.0      -2     -2.0
#
# [5 rows x 23 columns]

# %% [markdown]
# # Total Records | Percentage Graduated

# %%
print "Total economics major records: ",len(gpaDF)
print "Percentage graduated: ", 100-100*round(len(gpaDF.Graduated[gpaDF.Graduated==0])/1.0/len(gpaDF),3)
# Out:
# Total economics major records:  1988
# Percentage graduated:  35.5

# %% [markdown]
# # How many students Graduated?

# %%
graduatedDF = gpaDF[gpaDF['Graduated']==1]
len(graduatedDF)
# Out:
# 706

# %%
X = gpaDF[gpaDF.columns[col]]

# %% [markdown]
# # Silhouette 5-Fold CV

# %%
silScores5 = []

def callSilScore(kmeans,X):
    kfit = KD.kmeans(X,kmeans.cluster_centers_,metric = "cityblock")
    return metrics.silhouette_score(X,kfit[1],metric='cityblock')

for i in range(2,10):
    silScores5.append(cross_val_score(KMeans(n_clusters=i), X, scoring=callSilScore, cv=5, n_jobs=-1))

plt.figure(figsize=(10,5))
plt.errorbar(range(2,10),[score.mean() for score in silScores5], yerr=[score.std() for score in silScores5],label='5-Fold CV')
plt.legend(loc=1)
plt.xlim([2,9])
plt.xlabel("k clusters")
plt.ylabel("score")
plt.title("KMeans Silhouette Score")
plt.show()

# %% [markdown]
# # CH Index 5-Fold CV

# %%
chScores5 = []

def chScorer(kmeans,X):
    return CH_index(X.values, kmeans.labels_,kmeans.cluster_centers_)

for i in range(1,10):
    chScores5.append(cross_val_score(KMeans(n_clusters=i), X, scoring=chScorer, cv=5, n_jobs=-1))

plt.figure(figsize=(10,5))
plt.errorbar(range(1,10),[score.mean() for score in chScores5], yerr=[score.std() for score in chScores5],label='5-Fold CV')
plt.legend(loc=1)
plt.xlim([2,9])
plt.xlabel("k clusters")
plt.ylabel("score")
plt.title("CH Index")
plt.show()

# %% [markdown]
# # Cluster Metadata K=2

# %%
print "Now running KMeans on the FULL dataset, K=2"
k=2
classifier = KMeans(n_clusters=k, n_init=100)
classifier.fit(gpaDF[gpaDF.columns[col]])
y_pred = classifier.predict(gpaDF[gpaDF.columns[col]])

gpaDF['clusterLbl'] = y_pred

gpaDF_CL1 = deepcopy(gpaDF[gpaDF['clusterLbl']==0])
gpaDF_CL1_Perc_Graduating = len(gpaDF_CL1[gpaDF_CL1['Graduated']==1])/1.0/len(gpaDF_CL1)
print "\nSize of cluster 1: ",len(gpaDF_CL1)
print "Avg # terms: ", round(gpaDF_CL1.N_Terms.mean(),3)
print "Avg # inst credits: ", round(gpaDF_CL1.Inst_Cr.mean(),3)
print "Percentage graduating: ",round(gpaDF_CL1_Perc_Graduating,3)

gpaDF_CL2 = deepcopy(gpaDF[gpaDF['clusterLbl']==1])
gpaDF_CL2_Perc_Graduating = len(gpaDF_CL2[gpaDF_CL2['Graduated']==1])/1.0/len(gpaDF_CL2)
print "\n\nSize of cluster 2: ",len(gpaDF_CL2)
print "Avg # terms: ", round(gpaDF_CL2.N_Terms.mean(),3)
print "Avg # inst credits: ", round(gpaDF_CL2.Inst_Cr.mean(),3)
print "Percentage graduating: ",round(gpaDF_CL2_Perc_Graduating,3)
# Out:
# Now running KMeans on the FULL dataset, K=2
#
# Size of cluster 1:
#  846
# Avg # terms:  25.454
# Avg # inst credits:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-4d12e79eb1ec> in <module>()
#      11 print "\nSize of cluster 1: ",len(gpaDF_CL1)
#      12 print "Avg # terms: ", round(gpaDF_CL1.N_Terms.mean(),3)
# ---> 13 print "Avg # inst credits: ", round(gpaDF_CL1.Inst_Cr.mean(),3)
#      14 print "Percentage graduating: ",round(gpaDF_CL1_Perc_Graduating,3)
#      15
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/generic.pyc in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    3783                                               skipna=skipna)
#    3784                 return self._reduce(f, axis=axis,
# -> 3785                                     skipna=skipna, numeric_only=numeric_only)
#    3786             stat_func.__name__ = name
#    3787             return stat_func
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/series.pyc in _reduce(self, op, axis, skipna, numeric_only, filter_type, **kwds)
#    2007                 filter_type=None, **kwds):
#    2008         """ perform a reduction operation """
# -> 2009         return op(_values_from_object(self), skipna=skipna, **kwds)
#    2010
#    2011     def _reindex_indexer(self, new_index, indexer, copy):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/nanops.pyc in _f(*args, **kwargs)
#      46                                 'this dtype'.format(f.__name__.replace('nan',
#      47                                                                        '')))
# ---> 48             return f(*args, **kwargs)
#      49         return _f
#      50
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/nanops.pyc in f(values, axis, skipna, **kwds)
#      92                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#      93             except Exception:
# ---> 94                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#      95
#      96             return result
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/nanops.pyc in nanmean(values, axis, skipna)
#     264 def nanmean(values, axis=None, skipna=True):
#     265     values, mask, dtype, dtype_max = _get_values(values, skipna, 0)
# --> 266     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_max))
#     267     count = _get_counts(mask, axis)
#     268
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/nanops.pyc in _ensure_numeric(x)
#     666                 x = complex(x)
#     667             except Exception:
# --> 668                 raise TypeError('Could not convert %s to numeric' % str(x))
#     669     return x
#     670
#
# TypeError: Could not convert 0:0NA0:0NA0:0NA0:0NA0:0NA1:1B0:0NA1:1D0:0NA1:00:0NA1:1B0:0NA0:0NA0:0NA0:0NA0:0NA2:0F1:02:1D1:0F0:0NA1:1C1:0F0:0NA1:1B1:1B2:0F1:1C+3:0F0:0NA0:0NA0:0NA0:0NA1:1C0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA1:00:0NA0:0NA0:0NA0:0NA0:0NA4:01:1A0:0NA0:0NA1:0WU0:0NA1:1B3:0F1:1B+2:1D+1:1C1:1B1:1C2:0D0:0NA1:0F0:0NA1:1C1:1A1:1D0:0NA1:1C1:0F0:0NA2:01:1B0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA1:1C2:01:1B1:1B1:0F1:0F1:1C1:1D1:1A1:1D-2:02:1D3:0F0:0NA0:0NA0:0NA2:1C-0:0NA0:0NA0:0NA3:0F0:0NA0:0NA0:0NA1:1A1:1B1:1C1:1A0:0NA2:1D-0:0NA1:1D0:0NA1:0F0:0NA1:1B1:1B1:1C-1:1D0:0NA0:0NA1:00:0NA0:0NA1:1A0:0NA1:1B1:1C1:1A0:0NA1:1B3:0F0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA1:1D0:0NA0:0NA1:00:0NA3:1C0:0NA3:0F0:0NA0:0NA0:0NA1:1B0:0NA1:1B1:1C0:0NA0:0NA2:1C0:0NA0:0NA0:0NA0:0NA0:0NA1:1B1:1C1:1B-2:02:01:1A-0:0NA1:1D1:1C1:1B3:1C0:0NA0:0NA1:1B1:1A0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA1:1A2:1D0:0NA1:1C2:01:1C1:1D1:10:0NA0:0NA0:0NA1:1C1:1B0:0NA0:0NA0:0NA1:0I0:0NA1:1B0:0NA0:0NA2:0F0:0NA0:0NA0:0NA0:0NA0:0NA1:1C2:0F0:0NA1:1C0:0NA0:0NA0:0NA1:0F0:0NA0:0NA1:1C1:1B1:1C0:0NA0:0NA0:0NA1:1D0:0NA0:0NA3:0F0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA1:1B0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA1:1A0:0NA1:0F0:0NA3:01:1A1:1C0:0NA0:0NA1:1D0:0NA0:0NA1:1C0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA1:0F0:0NA2:1C1:1B0:0NA1:1D0:0NA1:1C0:0NA1:1D+0:0NA0:0NA0:0NA0:0NA1:1B+0:0NA0:0NA0:0NA0:0NA1:00:0NA0:0NA0:0NA0:0NA1:1A-0:0NA1:1C+0:0NA0:0NA1:1D+1:1C1:1B3:00:0NA4:1D0:0NA1:1C2:0F0:0NA0:0NA0:0NA1:0F1:1D1:1D+3:1A1:1D0:0NA1:0F0:0NA0:0NA1:1C2:01:1C0:0NA0:0NA0:0NA1:01:1B0:0NA0:0NA1:02:1D1:1B0:0NA1:1C+0:0NA0:0NA0:0NA0:0NA1:1D1:1D3:0F4:0F1:1C1:1C0:0NA1:1D0:0NA3:1C0:0NA0:0NA0:0NA0:0NA0:0NA1:1C1:1C0:0NA1:1B1:1C0:0NA0:0NA0:0NA1:0WU1:0F0:0NA0:0NA1:0F0:0NA0:0NA1:1B1:1B1:1B1:1D0:0NA1:0F0:0NA1:1C0:0NA2:02:1C+0:0NA0:0NA0:0NA0:0NA1:1B0:0NA0:0NA1:00:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA1:01:01:1B0:0NA0:0NA2:00:0NA1:1A0:0NA0:0NA0:0NA1:00:0NA0:0NA1:0WU0:0NA1:1D0:0NA2:0F1:1A0:0NA0:0NA0:0NA1:1D0:0NA0:0NA1:00:0NA1:1C1:1B1:1C1:1B0:0NA2:0F0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA1:0W0:0NA1:1D1:1C0:0NA0:0NA0:0NA3:0F0:0NA0:0NA0:0NA2:01:1C3:00:0NA1:1C0:0NA0:0NA0:0NA0:0NA0:0NA2:1D0:0NA0:0NA0:0NA1:0F0:0NA1:00:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA1:10:0NA1:1C1:1A0:0NA0:0NA1:1D0:0NA0:0NA0:0NA0:0NA1:1C1:1A1:1C1:1C0:0NA1:1C0:0NA0:0NA1:1C0:0NA2:01:1C1:1B0:0NA0:0NA0:0NA0:0NA0:0NA1:1B3:1B-0:0NA1:1C0:0NA1:1C0:0NA1:00:0NA0:0NA0:0NA0:0NA1:1B0:0NA0:0NA1:1A-0:0NA0:0NA1:00:0NA0:0NA0:0NA0:0NA0:0NA0:0NA1:0F1:01:0F0:0NA0:0NA1:1B-1:1B1:1C1:1B0:0NA0:0NA0:0NA1:0F0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA1:1D+2:0F0:0NA0:0NA1:1C2:0F0:0NA0:0NA1:10:0NA0:0NA0:0NA0:0NA0:0NA0:0NA3:1C2:00:0NA1:01:1B1:00:0NA1:1C0:0NA0:0NA0:0NA1:10:0NA0:0NA1:1C1:1D0:0NA0:0NA6:01:00:0NA1:00:0NA0:0NA0:0NA1:1D+0:0NA0:0NA2:0F1:1D+0:0NA0:0NA0:0NA1:1D0:0NA1:0B-1:1C1:1B0:0NA0:0NA3:0F0:0NA3:1D0:0NA0:0NA1:1A-1:1B1:1C3:00:0NA3:0F1:1C3:1A-3:01:1C2:1B-0:0NA1:1C1:1B0:0NA0:0NA0:0NA0:0NA0:0NA1:1B+1:0F1:1B1:1C0:0NA1:1B-0:0NA0:0NA0:0NA0:0NA1:1B2:00:0NA1:1A0:0NA1:1B1:1C0:0NA1:10:0NA0:0NA0:0NA0:0NA0:0NA1:1B1:1C1:00:0NA0:0NA1:1C1:1A2:1C-2:00:0NA1:1B0:0NA0:0NA0:0NA1:1C4:01:01:1A0:0NA1:1A-0:0NA0:0NA1:00:0NA2:00:0NA1:01:1B1:1A0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA1:1B0:0NA1:11:1B0:0NA0:0NA0:0NA0:0NA1:1B0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA1:1A1:00:0NA1:1A0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA1:1D0:0NA0:0NA0:0NA0:0NA1:1B0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA0:0NA1:01:1B1:1C0:0NA1:1B+0:0NA0:0NA1:02:01:01:1B0:0NA0:0NA0:0NA2:11:1B0:0NA1:1C0:0NA0:0NA1:1A0:0NA1:10:0NA0:0NA0:0NA0:0NA0:0NA0:0NA4:01:1A0:0NA1:1D0:0NA0:0NA1:1B1:1B0:0NA0:0NA1:1B0:0NA0:0NA2:1C+1:1C1:1C2:1B0:0NA1:0F1:1D1:1C2:1C2:1B+1:02:0F1:1D1:1B3:0W3:1C-1:1C1:1B+2:0F3:0F1:1C1:1B0:0NA1:01:1C2:00:0NA1:1C+1:1A1:01:1A1:01:0F0:0NA0:0NA0:0NA1:1A1:1D1:1B+1:1C2:0F1:1C+0:0NA1:1C+0:0NA0:0NA1:1D2:01:1B1:1D+1:1C-1:1C-0:0NA0:0NA1:1B1:1A1:1C0:0NA1:1C1:01:1A-0:0NA1:00:0NA4:0F1:1D1:1C3:01:1B-1:0F2:01:1C1:00:0NA2:0F4:02:1D2:0 to numeric

# %% [markdown]
# # N Terms, Inst Credit, Cluster Box Plots | K = 2

# %%
plt.figure(figsize=(9,9))
plt.subplot(2,1,1)
plt.boxplot([gpaDF_CL1.N_Terms,gpaDF_CL2.N_Terms])
plt.title("N Terms across cluster 1, 2")
plt.subplot(2,1,2)
plt.boxplot([gpaDF_CL1.Inst_Cr,gpaDF_CL2.Inst_Cr])
plt.title("Inst Credit across cluster 1, 2")
plt.savefig('box-plot-terms')
plt.show()

# %% [markdown]
# # LogReg, KMeans comparing FullSet to 3 Classes K=2

# %%
firstClassesIndices = []

for i in firstClasses:
    firstClassesIndices.append(list(gpaDF.columns).index(i))

plt.figure(figsize=(9,6))

#first 3 classes
X_train, X_test, y_train, y_test = train_test_split(gpaDF[gpaDF.columns[firstClassesIndices]], gpaDF['Graduated'])

classifier = KMeans(n_clusters=2, n_init=20)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.plot(false_positive_rate, true_positive_rate, 'b--', label='KMeans 3 Classes AUC = %0.2f' %roc_auc)

classifier = LogisticRegression()
classifier.fit(X_train, y_train)
y_pred = classifier.predict_proba(X_test)[:,1]
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.plot(false_positive_rate, true_positive_rate, 'b', label='Log Reg 3 Classes AUC = %0.2f' %roc_auc)


#full set
X_train, X_test, y_train, y_test = train_test_split(gpaDF[gpaDF.columns[col]], data['Graduated'])

classifier = KMeans(n_clusters=2, n_init=20)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.plot(false_positive_rate, true_positive_rate, 'g--', label='KMeans Full AUC = %0.2f' %roc_auc)

classifier = LogisticRegression()
classifier.fit(X_train, y_train)
y_pred = classifier.predict_proba(X_test)[:,1]
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.plot(false_positive_rate, true_positive_rate, 'g', label='Log Reg Full AUC = %0.2f' %roc_auc)


plt.title('Full Feature vs First Three Prediction')
plt.legend(loc='lower right')
plt.plot([0, 1], [0, 1], 'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig('full-feature-vs-three-feature-logreg-kmeans-ROC.png')
plt.show()

# %% [markdown]
# # Average Grades by Class Per Cluster K = 2

# %%
cl1_avg_grades = []
cl2_avg_grades = []

for i in gpaDF_CL1.columns[col].values:
    cl1_avg_grades.append(gpaDF_CL1[i].mean())
for i in gpaDF_CL2.columns[col].values:
    cl2_avg_grades.append(gpaDF_CL2[i].mean())

plt.figure(figsize=(12, 8))
plt.title('Avg Grades by Class per Cluster k=2')
plt.scatter(range(1,1+len(col)),cl1_avg_grades,c='r',marker='x',label="Cl 1")
plt.scatter(range(1,1+len(col)),cl2_avg_grades,c='b',marker='x',label="CL 2")
plt.xticks(range(1,1+len(col)),gpaDF[gpaDF.columns[col]].columns.values,rotation=70)
plt.legend()
plt.savefig('avg-grade-per-cluster')
plt.show()
